# %% [markdown]
# # Math Detection Using YOLOv3 and Tensorflow

# %% [markdown]
# # Step I
# First, upload your train, test and validation data to drive and then mount it on colab.

# %%
from google.colab import drive
drive.mount('gdrive')
# Out:
# Mounted at gdrive

# %% [markdown]
# # Step II
# Clone the repository on colab.

# %%
# !git clone "https://github.com/wizyoung/YOLOv3_TensorFlow.git"
# Out:
# Cloning into 'YOLOv3_TensorFlow'...
# remote: Enumerating objects: 222, done.
# remote: Total 222 (delta 0), reused 0 (delta 0), pack-reused 222
# Receiving objects: 100% (222/222), 3.16 MiB | 28.92 MiB/s, done.
# Resolving deltas: 100% (126/126), done.

# %% [markdown]
# #Step III
# The repository has pretrained weights. Download the weights and place them at the location stated in the repo. Here, I have the weights uploaded on my drive, therefore, I am using copy command to copy weights to copy of repo created on colab.

# %%
# !cp "/content/gdrive/My Drive/Colab_Notebooks/yolov3.weights" /content/YOLOv3_TensorFlow/data/darknet_weights

# %%
import os #Import os module

# %%
# !cp -r "/content/gdrive/My Drive/Colab_Notebooks/Test" "/content/YOLOv3_TensorFlow/data/my_data" # Copy testing data to YOLOv3 cloned repository.

# %%
# !cp -r "/content/gdrive/My Drive/Colab_Notebooks/Train" "/content/YOLOv3_TensorFlow/data/my_data" # Copy training data to YOLOv3 to cloned repository.

# %% [markdown]
# This implementation uses Tensorflow version 1.8
#
# ---

# %%
# %tensorflow_version 1.8
# Out:
# `%tensorflow_version` only switches the major version: 1.x or 2.x.
# You set: `1.8`. This will be interpreted as: `1.x`.
#
#
# TensorFlow 1.x selected.

# %%
os.chdir("/content/YOLOv3_TensorFlow") # change directory to cloned repo.

# %% [markdown]
# # Step IV
# 1.  After converting weights is done, replace the address of training file in get_kmeans.py file line no 142 with absolute path of train.txt file "/content/YOLOv3_TensorFlow/data/my_data/train.txt".
# 2.   In the file, data_utils.py, go to line no 191, press ENTER and add mode = str(mode)

# %%
# !python get_kmeans.py
# Out:
# anchors are:
# 5,8, 7,8, 10,8, 14,10, 25,11, 37,10, 60,11, 114,12, 233,28
# the average iou is:
# 0.7782044334444049

# %% [markdown]
# # Step V
# ### 1. Upload train.txt, test.txt and val.txt ( prepared in YOLOv3 format as mentioned in Repo point no 7.) in /content/YOLOv3_TensorFlow/data/my_data folder.
# ### 2. In convert_weight.py, change classes from 80 to "classes" in your dataset. (here 1)

# %% [markdown]
# # Step VI
#
#
# 1.   Copy the anchors generated by code in the cell above in anchors.txt file.
# 2.   Create data.names file with every line as label for a class and name the bounding boxes with appropriate label index as stated in github Repo.
# 3.   Upload both, data.names & anchors.txt to "/content/YOLOv3_TensorFlow/data"

# %%
# !python /content/YOLOv3_TensorFlow/convert_weight.py # to convert weights
# Out:
# WARNING:tensorflow:
# The TensorFlow contrib module will not be included in TensorFlow 2.0.
# For more information, please see:
#   * https://github.com/tensorflow/community/blob/master/rfcs/20180907-contrib-sunset.md
#   * https://github.com/tensorflow/addons
#   * https://github.com/tensorflow/io (for I/O related ops)
# If you depend on functionality not listed there, please file an issue.
#
# WARNING:tensorflow:From /content/YOLOv3_TensorFlow/convert_weight.py:22: The name tf.Session is deprecated. Please use tf.compat.v1.Session instead.
#
# 2020-10-14 05:15:37.253888: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcuda.so.1
# 2020-10-14 05:15:37.302933: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# ...

# %% [markdown]
# # Step VII
# In Args.py file :
# 1. Line 16, change anchor path to "/content/YOLOv3_TensorFlow/data/anchors.txt"
# 2. Line 17, change class_name_path to "/content/YOLOv3_TensorFlow/data/data.names"

# %%
# !python train.py
# Out:
# WARNING:tensorflow:
# The TensorFlow contrib module will not be included in TensorFlow 2.0.
# For more information, please see:
#   * https://github.com/tensorflow/community/blob/master/rfcs/20180907-contrib-sunset.md
#   * https://github.com/tensorflow/addons
#   * https://github.com/tensorflow/io (for I/O related ops)
# If you depend on functionality not listed there, please file an issue.
#
# WARNING:tensorflow:From train.py:24: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# WARNING:tensorflow:From /tensorflow-1.15.2/python3.6/tensorflow_core/python/ops/array_ops.py:1475: where (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# ...

# %% [markdown]
# # Step VIII:
# Now, we have our model saved here, /content/YOLOv3_TensorFlow/checkpoint/.
#
#
# 1.   Open test_single_image.py and commit following changes.
# 2.   Line 20 - change yolo_anchors to anchors.txt.
# 3.   Line 26 - change coco.names to data.names.
# 4.   Line 60 - Replace args.restore_path with tf.train.latest_checkpoint('/content/YOLOv3_TensorFlow/checkpoint/')
# 5. Comment out line no 84 using #.
# 6. Edit line no 85 from cv2.imwrite('detection_result.jpg', img_ori) to cv2.imwrite('/content/YOLOv3_TensorFlow/detection_result.jpg',img_ori).

# %%
# !python eval.py
# Out:
# WARNING:tensorflow:
# The TensorFlow contrib module will not be included in TensorFlow 2.0.
# For more information, please see:
#   * https://github.com/tensorflow/community/blob/master/rfcs/20180907-contrib-sunset.md
#   * https://github.com/tensorflow/addons
#   * https://github.com/tensorflow/io (for I/O related ops)
# If you depend on functionality not listed there, please file an issue.
#
# WARNING:tensorflow:From eval.py:68: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# WARNING:tensorflow:From /tensorflow-1.15.2/python3.6/tensorflow_core/python/ops/array_ops.py:1475: where (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# ...

# %%
# !python test_single_image.py "/content/YOLOv3_TensorFlow/data/my_data/Test/JMKU_1971_377_379/2.png"
# Out:
# WARNING:tensorflow:
# The TensorFlow contrib module will not be included in TensorFlow 2.0.
# For more information, please see:
#   * https://github.com/tensorflow/community/blob/master/rfcs/20180907-contrib-sunset.md
#   * https://github.com/tensorflow/addons
#   * https://github.com/tensorflow/io (for I/O related ops)
# If you depend on functionality not listed there, please file an issue.
#
# WARNING:tensorflow:From test_single_image.py:48: The name tf.Session is deprecated. Please use tf.compat.v1.Session instead.
#
# 2020-10-14 07:49:36.000904: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcuda.so.1
# 2020-10-14 07:49:36.039555: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# ...
